# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgetstechnology/financas/blob/master/calculando_a_taxa_de_retorno_dos_indices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers =['^GSPC', '^IXIC', '^GDAXI']
ind_data = pd.DataFrame()

for t in tickers:
  ind_data[t] = wb.DataReader(t, data_source = 'yahoo', start = '1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059
# 1997-01-03  748.030029  1310.680054  2863.260010
# 1997-01-06  747.650024  1316.400024  2890.199951
# 1997-01-07  753.229980  1327.729980  2876.340088
# 1997-01-08  748.409973  1320.349976  2904.080078

# %%
ind_data.tail()
# Out:
#                   ^GSPC        ^IXIC        ^GDAXI
# Date
# 2020-01-02  3257.850098  9092.190430  13385.929688
# 2020-01-03  3234.850098  9020.769531  13219.139648
# 2020-01-06  3246.280029  9071.469727  13126.990234
# 2020-01-07  3237.179932  9068.580078  13226.830078
# 2020-01-08  3253.050049  9129.242188  13320.179688

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 2020-01-02  0.008379  0.013328       NaN
# 2020-01-03 -0.007060 -0.007855 -0.012460
# 2020-01-06  0.003533  0.005620 -0.006971
# 2020-01-07 -0.002803 -0.000319  0.007606
# 2020-01-08  0.004902  0.006689  0.007058

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.081763
# ^IXIC     0.115150
# ^GDAXI    0.079418
# dtype: float64

# %%
tickers = ['PG', '^GSPC', '^DJI']

data_2 = pd.DataFrame()
for t in tickers :
  data_2[t] = wb.DataReader(t, data_source = 'yahoo', start = '2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2020-01-02  123.410004  3257.850098  28868.800781
# 2020-01-03  122.580002  3234.850098  28634.880859
# 2020-01-06  122.750000  3246.280029  28703.380859
# 2020-01-07  121.989998  3237.179932  28583.679688
# 2020-01-08  122.510002  3253.050049  28745.089844

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize = (15, 6));
plt.show()
