# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgetstechnology/financas/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **9 Tecnicas de visualizações efetivo para análise de dados com Pandas**

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
data = load_iris()
df = pd.DataFrame(data['data'], columns = data['feature_names'])
df['species'] = data['target']
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 0                5.1               3.5  ...               0.2        0
# 1                4.9               3.0  ...               0.2        0
# 2                4.7               3.2  ...               0.2        0
# 3                4.6               3.1  ...               0.2        0
# 4                5.0               3.6  ...               0.2        0
#
# [5 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df.species.unique()
# Out:
# array([0, 1, 2])

# %%
df.plot()

# %%
df.plot.scatter(x='sepal length (cm)', y='sepal width (cm)')

# %%
df.plot.scatter(x='sepal length (cm)', y='petal length (cm)')

# %%
columns = ['sepal length (cm)', 'petal length (cm)', 'petal width (cm)', 'sepal width (cm)']
df[columns].plot.area()

# %%
df.groupby('species').mean().plot.bar()

# %%
df.groupby('species').count().plot.pie(y='sepal length (cm)')

# %%
import matplotlib.pyplot as plt
df.hist()
plt.tight_layout()

# %%
df.plot.kde(subplots=True, figsize=(5,9))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc686becc0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc67e793c8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc62a4f2e8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc628286a0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc62780ef0>],
#       dtype=object)

# %%
columns = ['sepal length (cm)', 'petal length (cm)', 'petal width (cm)', 'sepal width (cm)']
df[columns].plot.box()
plt.xticks(rotation='vertical')
# Out:
# (array([1, 2, 3, 4]), <a list of 4 Text major ticklabel objects>)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc6290c400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc628d2908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc626e8b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc6271ddd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc626de080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc626912e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc62645550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc625f8780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc625f87f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc62560c88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc62594ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc62556198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc62507400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc624bc668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc624708d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc62423b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc62456fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc624143c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc623c6748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc62376ac8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc6232ce48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc622e9208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc6231c588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc622ce908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc62280c88>]],
#       dtype=object)
