# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgetstechnology/financas/blob/master/MonteCarlo_prevendo_o_lucro_bruto1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `Projetando Receitas e despesas futuras em uma empresa`

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#rodando 1000 simulações de Receitas esperadas
rev_m = 170 #receita média sperada
rev_stdev = 20 #desvio padrão
interations = 1000

# %%
rev = np.random.normal(rev_m, rev_stdev, interations) # gerador aleatório de distribuição
rev
# Out:
# array([164.17796602, 188.14153873, 184.15233104, 151.89638256,
#        135.56791212, 168.41869079, 204.53457208, 144.20651352,
#        144.4602063 , 149.49956374, 172.96016705, 183.1727101 ,
#        147.7201662 , 194.35862466, 199.37414142, 167.35838161,
#        178.3127462 , 155.7811553 , 164.73187428, 167.17926189,
#        168.01747002, 170.90088164, 162.92453301, 163.47597296,
#        151.88412071, 153.2142915 , 210.81470205, 173.68144752,
#        179.13363599, 161.61276021, 162.71473978, 153.48942851,
#        156.76642714, 153.86187919, 154.38800268, 189.15521046,
#        149.88408826, 197.19969424, 173.03151515, 167.04553576,
#        153.0881744 , 184.9567769 , 147.38634256, 174.07071864,
#        208.76832144, 172.78859135, 164.86487753, 193.9344974 ,
#        192.43876146, 174.03151521, 127.98074805, 178.94699749,
#        202.15072505, 165.00487047, 187.84803198, 167.87480626,
#        158.66306176, 144.00363717, 151.27471727, 160.79886475,
# ...

# %%
plt.figure(figsize = (15, 6))
plt.plot(rev)
plt.show()

# %%
COGS = - (rev * np.random.normal(0.6, 0.1)) #gasto de 60% com desvio padrão de 10%
plt.figure(figsize=(15, 6))
plt.plot(COGS)
plt.show()

# %%
COGS.mean()
# Out:
# -105.64667576848116

# %%
COGS.std()
# Out:
# 12.285076047401288
